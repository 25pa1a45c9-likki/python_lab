# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a45c9-likki/python_lab/blob/main/python__5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
t=(1,2,3,4,5,"hello")
print(t)
# Out:
# (1, 2, 3, 4, 5, 'hello')

# %%
print(type(t))
# Out:
# <class 'tuple'>

# %%
t1=()
print(type(t1))
# Out:
# <class 'tuple'>

# %%
print(t[0])
# Out:
# 1

# %%
import sys
l=[]
t=()
print(sys.getsizeof(l))
print(sys.getsizeof(t))
# Out:
# 56
# 40

# %%
print(t)
# Out:
# ()

# %%
t1=(1,2,3)
t2=(9,7,8)
print(t1+t2)
print(t1*4)
for i in t1:
  print(i)
# Out:
# (1, 2, 3, 9, 7, 8)
# (1, 2, 3, 1, 2, 3, 1, 2, 3, 1, 2, 3)
# 1
# 2
# 3

# %%
print(sum(t1))
print(max(t1))
# Out:
# 6
# 3

# %%
print(t1.count(1))
print(t1.index(3))
# Out:
# 1
# 2

# %%
t3=tuple(map(int,input("enter tuple element:").split()))
print(t3)
# Out:
# enter tuple element:1 2 3
# (1, 2, 3)

# %%
print(list(zip(t1,t2)))
# Out:
# [(1, 9), (2, 7), (3, 8)]

# %%
# Create tuples containing name, age, address and college

student1 = ("Rahul", 20, "Chennai", "ABC College")
student2 = ("Priya", 19, "Madurai", "XYZ College")
print(student1+student2)
# Out:
# ('Rahul', 20, 'Chennai', 'ABC College', 'Priya', 19, 'Madurai', 'XYZ College')

# %%
# Program to count the number of vowels in a string

s = input("Enter a string: ")

vowels = s.lower().count('a') + s.lower().count('e') + s.lower().count('i') + s.lower().count('o') + s.lower().count('u')

print("Number of vowels:", vowels)
# Out:
# Enter a string: likitha
# Number of vowels: 3

# %%
#sets
