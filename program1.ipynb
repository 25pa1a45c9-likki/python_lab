# %% [markdown]
# <a href="https://colab.research.google.com/github/25pa1a45c9-likki/python_lab/blob/main/program1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print(2+3)
# Out:
# 5

# %%
print (int(input()))
